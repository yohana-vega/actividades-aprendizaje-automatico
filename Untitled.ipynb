# %%
import pandas as pd

# %%
ventas = pd.read_csv("ventas (1).csv")
ventas.head()
# Out:
#    id_venta       fecha  producto  cantidad  precio_unitario
# 0         1  2026-01-10  Notebook         2             1200
# 1         2  2026-01-12     Mouse         5               25
# 2         3  2026-01-15   Teclado         3               45
# 3         4  2026-01-18   Monitor         1              300

# %%
clientes = pd.read_json("clientes.json")
len(clientes)
# Out:
# 3

# %%
inventario = pd.read_excel("inventario.xlsx")
inventario.describe()
# Out:
#        id_producto      stock       precio
# count     4.000000   4.000000     4.000000
# mean      2.500000  26.250000   392.500000
# std       1.290994  17.969882   552.697928
# min       1.000000  10.000000    25.000000
# 25%       1.750000  13.750000    40.000000
# 50%       2.500000  22.500000   172.500000
# 75%       3.250000  35.000000   525.000000
# max       4.000000  50.000000  1200.000000

# %%
ventas["total"] = ventas["cantidad"] * ventas["precio_unitario"]
ventas
# Out:
#    id_venta       fecha  producto  cantidad  precio_unitario  total
# 0         1  2026-01-10  Notebook         2             1200   2400
# 1         2  2026-01-12     Mouse         5               25    125
# 2         3  2026-01-15   Teclado         3               45    135
# 3         4  2026-01-18   Monitor         1              300    300
